# %%
# !pip install selenium
# !pip install webdriver_manager
# !pip install langdetect
# Out:
# Requirement already satisfied: selenium in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from selenium) (1.25.11)
# Requirement already satisfied: webdriver_manager in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: requests in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from webdriver_manager) (2.24.0)
# Requirement already satisfied: crayons in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from webdriver_manager) (0.4.0)
# Requirement already satisfied: configparser in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from webdriver_manager) (5.0.2)
# Requirement already satisfied: colorama in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from crayons->webdriver_manager) (0.4.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver_manager) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver_manager) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver_manager) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from requests->webdriver_manager) (3.0.4)
# Requirement already satisfied: langdetect in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (1.0.9)
# Requirement already satisfied: six in /Users/carlosperezricardo/opt/anaconda3/lib/python3.8/site-packages (from langdetect) (1.15.0)

# %%
from  selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import os
from os.path  import basename
import requests
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys

import numpy as np

import re

from langdetect import detect

# %%
reviews = pd.read_csv('ABaC_reviews.csv', index_col = 0)
#reviews = pd.read_csv('ABaC_reviews_translated.csv', index_col = 0)
reviews
# Out:
#                                                    body
# 0     Es la sensación que me ha transportado esta ex...
# 1     Es una gran experiencia y nos ha gustado mucho...
# 2     Comer en Abac es una experiencia vital que rec...
# 3     Una pena.La comida sin pena ni gloria, de un 3...
# 4     La comida nada sorprendente y más bien aburrid...
# ...                                                 ...
# 1590  Tres de nosotros fuimos a almorzar allí durant...
# 1591  en un hermoso jardín privada se encuentra un h...
# 1592  Stark ambiente moderno en un jardín privado en...
# 1593  esperábamos poder alojarnos en Abac, pero, des...
# 1594  Éste fue el mejor restaurante que comimos en d...
#
# [1595 rows x 1 columns]

# %%
web_link = 'https://translate.systran.net/'

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [/Users/carlosperezricardo/.wdm/drivers/chromedriver/mac64/93.0.4577.63/chromedriver] found in cache

# %%
driver.get(web_link)
time.sleep(4)

# %%
text = 'Muy lindo y  diferente admirar el arte de otra manera.Buena experiencia para los niños, el movimiento y las luces lo hacen muy divertido'

# %%
detect(text)
# Out:
# 'es'

# %%
#inputEditor
driver.find_element_by_class_name("form-control").send_keys(text)

# %%
content = driver.page_source
soup = BeautifulSoup(content)

# %%
translation = soup.find(id="outputEditor")
translation.text
# Out:
# ''

# %%
# Clean result
text_area = driver.find_element_by_class_name('form-control')
#driver.find_element_by_class_name('form-control').send_keys(Keys.DELETE)

# %%
for i in range(len(text)):
    text_area.send_keys(Keys.BACKSPACE)

# %%
#reviews['lang'] = '' 
#reviews['translation'] = ''

# %%
reviews.head()
# Out:
#                                                 body lang translation
# 0  Es la sensación que me ha transportado esta ex...
# 1  Es una gran experiencia y nos ha gustado mucho...
# 2  Comer en Abac es una experiencia vital que rec...
# 3  Una pena.La comida sin pena ni gloria, de un 3...
# 4  La comida nada sorprendente y más bien aburrid...

# %%
reviews.iloc[524]['translation']
# Out:
# ''

# %%
for index, review in reviews.iterrows():
    body = review['body']
    trans = review['translation']
    
    #print(trans)
    #print(type(trans))

    lang = detect(body)
    #print(lang)
    reviews.iloc[index]['lang'] = lang
    #print(body, '\n')

    text_area = driver.find_element_by_class_name('form-control')

    if lang != 'en' and (type(trans) == np.float or trans == ""):
        try:
            driver.find_element_by_class_name("form-control").send_keys( body )
            time.sleep(14)

            content = driver.page_source
            soup = BeautifulSoup(content)    

            translation_ = soup.find(id="outputEditor")
            translation = translation_.text
            reviews.iloc[index]['translation'] = translation

            #print(body,'\n')
            #print(translation,'\n')
            for i in range(len(body)):
                text_area.send_keys(Keys.BACKSPACE)
            time.sleep(8)
        except: 
            for i in range(len(body)):
                text_area.send_keys(Keys.BACKSPACE)
            print('skip',index)
            time.sleep(8)
    else:
        print('not searched',index)
        if (type(trans) != np.float or trans == ""):
            reviews.iloc[index]['translation'] = trans
            pass
        else:    
            translation = body
            reviews.iloc[index]['translation'] = translation
    
    #print(translation, '\n')
    print(index)
# Out:
# not searched 0
# 0
# not searched 1
# 1
# not searched 2
# 2
# not searched 3
# 3
# not searched 4
# 4
# not searched 5
# 5
# not searched 6
# 6
# not searched 7
# 7
# not searched 8
# 8
# not searched 9
# 9
# not searched 10
# 10
# not searched 11
# 11
# not searched 12
# 12
# not searched 13
# 13
# not searched 14
# 14
# not searched 15
# 15
# not searched 16
# 16
# not searched 17
# 17
# not searched 18
# 18
# not searched 19
# 19
# not searched 20
# 20
# not searched 21
# 21
# not searched 22
# 22
# not searched 23
# 23
# not searched 24
# 24
# not searched 25
# 25
# not searched 26
# 26
# not searched 27
# 27
# not searched 28
# 28
# skip 29
# 29
# not searched 30
# 30
# not searched 31
# 31
# not searched 32
# 32
# not searched 33
# 33
# not searched 34
# 34
# not searched 35
# 35
# not searched 36
# 36
# not searched 37
# 37
# not searched 38
# 38
# not searched 39
# 39
# not searched 40
# 40
# not searched 41
# 41
# not searched 42
# 42
# not searched 43
# 43
# not searched 44
# 44
# not searched 45
# 45
# not searched 46
# 46
# not searched 47
# 47
# not searched 48
# 48
# not searched 49
# 49
# not searched 50
# 50
# not searched 51
# 51
# not searched 52
# 52
# not searched 53
# 53
# not searched 54
# 54
# not searched 55
# 55
# not searched 56
# 56
# not searched 57
# 57
# not searched 58
# 58
# not searched 59
# 59
# not searched 60
# 60
# not searched 61
# 61
# not searched 62
# 62
# not searched 63
# 63
# not searched 64
# 64
# not searched 65
# 65
# not searched 66
# 66
# not searched 67
# 67
# not searched 68
# 68
# not searched 69
# 69
# not searched 70
# 70
# not searched 71
# 71
# not searched 72
# 72
# not searched 73
# 73
# not searched 74
# 74
# not searched 75
# 75
# not searched 76
# 76
# not searched 77
# 77
# not searched 78
# 78
# not searched 79
# 79
# not searched 80
# 80
# not searched 81
# 81
# not searched 82
# 82
# not searched 83
# 83
# not searched 84
# 84
# not searched 85
# 85
# not searched 86
# 86
# not searched 87
# 87
# not searched 88
# 88
# not searched 89
# 89
# not searched 90
# 90
# not searched 91
# 91
# not searched 92
# 92
# not searched 93
# 93
# not searched 94
# 94
# not searched 95
# 95
# not searched 96
# 96
# not searched 97
# 97
# not searched 98
# 98
# not searched 99
# 99
# not searched 100
# 100
# not searched 101
# 101
# not searched 102
# 102
# not searched 103
# 103
# not searched 104
# 104
# not searched 105
# 105
# not searched 106
# 106
# not searched 107
# 107
# not searched 108
# 108
# not searched 109
# 109
# not searched 110
# 110
# not searched 111
# 111
# not searched 112
# 112
# not searched 113
# 113
# not searched 114
# 114
# not searched 115
# 115
# not searched 116
# 401
# not searched 402
# 402
# not searched 403
# 403
# not searched 404
# 404
# skip 405
# 405
# not searched 406
# 406
# not searched 407
# 407
# not searched 408
# 408
# not searched 409
# 409
# not searched 410
# 410
# not searched 411
# 411
# not searched 412
# 412
# not searched 413
# 413
# not searched 414
# 414
# not searched 415
# 415
# not searched 416
# 416
# not searched 417
# 417
# not searched 418
# 418
# 419
# not searched 420
# 420
# not searched 421
# 421
# not searched 422
# 422
# not searched 423
# 423
# not searched 424
# 424
# not searched 425
# 425
# not searched 426
# 426
# not searched 427
# 427
# not searched 428
# 428
# not searched 429
# 429
# not searched 430
# 430
# not searched 431
# 431
# not searched 432
# 432
# not searched 433
# 433
# not searched 434
# 434
# not searched 435
# 435
# not searched 436
# 436
# not searched 437
# 437
# not searched 438
# 438
# not searched 439
# 439
# not searched 440
# 440
# not searched 441
# 441
# not searched 442
# 442
# not searched 443
# 443
# 444
# not searched 445
# 445
# 446
# not searched 447
# 447
# not searched 448
# 448
# not searched 449
# 449
# not searched 450
# 450
# not searched 451
# 451
# not searched 452
# 452
# not searched 453
# 453
# not searched 454
# 454
# not searched 455
# 455
# not searched 456
# 456
# not searched 457
# 457
# not searched 458
# 458
# not searched 459
# 459
# not searched 460
# 460
# not searched 461
# 461
# not searched 462
# 462
# not searched 463
# 463
# 464
# not searched 465
# 465
# not searched 466
# 466
# not searched 467
# 467
# not searched 468
# 468
# not searched 469
# 469
# not searched 470
# 470
# not searched 471
# 471
# not searched 472
# 472
# skip 473
# 473
# not searched 474
# 474
# not searched 475
# 475
# not searched 476
# 476
# not searched 477
# 477
# 478
# skip 479
# 479
# 480
# 481
# 482
# 483
# skip 484
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-505-9b9bc2e6c8ac> in <module>
#      29             for i in range(len(body)):
# ---> 30                 text_area.send_keys(Keys.BACKSPACE)
#      31             time.sleep(8)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=93.0.4577.63)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-505-9b9bc2e6c8ac> in <module>
#      32         except:
#      33             for i in range(len(body)):
# ---> 34                 text_area.send_keys(Keys.BACKSPACE)
#      35             print('skip',index)
#      36             time.sleep(8)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     475                 value = self._upload(local_file)
#     476
# --> 477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
#     479                        'value': keys_to_typing(value)})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=93.0.4577.63)

# %%
reviews.to_csv('ABaC_reviews_translated.csv')

# %%
reviews
# Out:
#                                                    body lang  \
# 0     Es la sensación que me ha transportado esta ex...   es
# 1     Es una gran experiencia y nos ha gustado mucho...   es
# 2     Comer en Abac es una experiencia vital que rec...   es
# 3     Una pena.La comida sin pena ni gloria, de un 3...   es
# 4     La comida nada sorprendente y más bien aburrid...   es
# ...                                                 ...  ...
# 1590  Tres de nosotros fuimos a almorzar allí durant...
# 1591  en un hermoso jardín privada se encuentra un h...
# 1592  Stark ambiente moderno en un jardín privado en...
# 1593  esperábamos poder alojarnos en Abac, pero, des...
# 1594  Éste fue el mejor restaurante que comimos en d...
#
#                                             translation
# 0     It is the feeling that this experience has car...
# 1     It's a great experience and we really liked it...
# 2     Eating at Abac is a vital experience that I re...
# 3     A pity.The food without pity or glory, of a 3 ...
# 4     The food is not surprising and rather boring. ...
# ...                                                 ...
# 1590
# 1591
# 1592
# 1593
# 1594
#
# [1595 rows x 3 columns]

# %%
reviews[reviews["translation"] != ""]
# Out:
#                                                   body lang  \
# 0    Es la sensación que me ha transportado esta ex...   es
# 1    Es una gran experiencia y nos ha gustado mucho...   es
# 2    Comer en Abac es una experiencia vital que rec...   es
# 3    Una pena.La comida sin pena ni gloria, de un 3...   es
# 4    La comida nada sorprendente y más bien aburrid...   es
# ..                                                 ...  ...
# 472  Fuimos a celebrar un cumpleaños. Quedamos enca...   es
# 474  La verdad que esperaba un pocao m´ças por lo q...   es
# 475  Servicio muy malo, poco atento, comida en la q...   es
# 476  Teníamos muchas ganas e íbamos con muchas expe...   es
# 477  Decir que no disfrutamos sería faltar a la ver...   es
#
#                                            translation
# 0    It is the feeling that this experience has car...
# 1    It's a great experience and we really liked it...
# 2    Eating at Abac is a vital experience that I re...
# 3    A pity.The food without pity or glory, of a 3 ...
# 4    The food is not surprising and rather boring. ...
# ..                                                 ...
# 472  We went to celebrate a birthday. We were delig...
# 474  The truth was that I was expecting a little m'...
# 475  Very bad service, not very attentive, food in ...
# 476  We wanted very much and we went with a lot of ...
# 477  To say we don't enjoy ourselves would be a lac...
#
# [471 rows x 3 columns]

# %%
#reviews.iloc[14]['translation'] = ''
reviews.iloc[149]['translation']
# Out:
# "The attention and the care given to the guests are unbeatable: they make sure they know each customer's intolerances and allergies and if so change the ingredient. The first few dishes are served in the kitchen, which shows the organization, coordination and cleanliness of the place. Not to mention that the tasting menu is extensive we end up satisfied, very well presented and with intense flavors, but at the same time respecting the product."

# %%
review = reviews.iloc[38] 
trans = review['translation']
print(trans)
# Out:
# Pues como ya pude verificar que el restaurante estaba bien, le compré un bono regalo para dos persona a mi pareja. Por suerte me eligió como acompañante y pude disfrutar de una nueva experiencia en el Abac. En primer lugar, cuando intentamos hacer la reserva online con el bono no podíamos. Nos pusimos en contacto con el restaurante vía email y nos solucionaron el problema. Aparte,el bono era de menú abac y no del gran abac y actualmente solo se sirve el gran abac. Nos adaptaron el menú quitando tres platos. Llegamos en coche y pudimos aparcar en el parking sin ningún problema, llamando al interfono que hay en la entrada de avinguda tibidado. A la salida del parking, nos esperaba una persona que nos acompañó a nuestra mesa. Esta vez la sala no estaba tan bien. Me gustó más la sala en que estuve la primera vez, que era más espaciosa y creo que más elegante. La comida fue igual de excelente, volviendo a destacar la sopa de cebolla, y el calamar a la romana me pareció mejor. No me apasionó mucho el plato de carne. Los postres muy ricos pero eché en falta uno que fuese tan espléndido como el oda a lo efímero. La selección de copas del sumiller excelente, sobre todo el dulce. El servicio muy bueno, aunque puede molestar un poco el ajetreo que llevan y puede conducir a errores. En el restaurante de la Ruscalleda no percibí tanto movimiento,parecía más tranquilo. Por suerte Jordi Cruz estaba, sabía que a mi pareja le haría ilusión,y pasó por las mesas a saludarte y hacerse fotos a quien se lo pidiese. Muy amable. La terraza donde se toma el café está bien, pero no supera al jardín que tenía el sant pau. La música ambiente para mi gusto sobra. La segunda vez que he ido estuvo mejor porque pude compartir la experiencia. La verdad, creo que vales la pena.

# %%
print(type(trans) == np.float)
# Out:
# True
